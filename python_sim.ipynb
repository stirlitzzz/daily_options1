# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./algo_data/vol_surfaces2.csv")
df['minute'] = pd.to_datetime(df['minute'])
df['minute'].apply(lambda x: x.tz).unique()
#for each row find 16:17:00 and compute years to maturity where maturity is 16:17:00 for each row

def get_years_to_maturity(row):
    maturity = pd.Timestamp(row['minute'].date(), tz=row['minute'].tz) + pd.Timedelta(hours=16, minutes=17)
    return (maturity - row['minute']).seconds / (365.25 * 24 * 60 * 60)

df['years_to_maturity'] = df.apply(get_years_to_maturity, axis=1)
df.loc[df['implied_spot'] <= .07, ['implied_spot', 'atm_vol', 'slope', 'quadratic_term', 'scaled_slope', 'scaled_quadratic']] = np.nan
df.loc[df['atm_vol'] <= .03, ['implied_spot', 'atm_vol', 'slope', 'quadratic_term', 'scaled_slope', 'scaled_quadratic']] = np.nan
# Forward fill the NaN values
df=df.ffill().infer_objects(copy=False)
# Out:
# /var/folders/c1/dv7w7b2x49j3spqsxnz6y_sw0000gn/T/ipykernel_53828/1781164678.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df['minute'] = pd.to_datetime(df['minute'])

# %%
df
# Out:
#                            minute  implied_spot   atm_vol     slope  \
# 0       2024-01-02 09:31:00-05:00    472.563933  0.189797 -0.386711
# 1       2024-01-02 09:32:00-05:00    472.705855  0.183684 -0.393608
# 2       2024-01-02 09:33:00-05:00    472.784149  0.181348 -0.452450
# 3       2024-01-02 09:34:00-05:00    472.743159  0.180591 -0.333196
# 4       2024-01-02 09:35:00-05:00    472.689797  0.178740 -0.421782
# ...                           ...           ...       ...       ...
# 112994  2025-03-03 15:57:00-05:00    583.217755  0.433006 -0.643380
# 112995  2025-03-03 15:58:00-05:00    583.318760  0.399562 -1.119237
# 112996  2025-03-03 15:59:00-05:00    583.589449  0.375949 -6.439821
# 112997  2025-03-03 16:00:00-05:00    584.010249  0.336107  0.051465
# 112998  2025-03-03 16:01:00-05:00    584.391746  0.342320 -5.064520
#
#         quadratic_term  scaled_slope  scaled_quadratic  open_price  \
# 0           133.447533     -0.001074          0.103011     472.160
# 1           156.933023     -0.001092          0.120842     472.530
# 2           182.755226     -0.001254          0.140378     472.680
# 3           179.169754     -0.000922          0.137283     472.760
# 4           178.336217     -0.001166          0.136305     472.685
# ...                ...           ...               ...         ...
# 112994     2250.084372     -0.000397          0.085561     583.120
# 112995     2824.657505     -0.000673          0.102039     583.220
# 112996     3647.324778     -0.003767          0.124823     583.320
# 112997     3648.685396      0.000029          0.117932     583.570
# 112998     4506.573475     -0.002793          0.137093     584.010
#
#         high_price  low_price  close_price     volume      vwap  \
# 0           472.67    472.050     472.5300  1190522.0  472.9271
# 1           472.70    472.365     472.6812   756655.0  473.3993
# 2           472.80    472.650     472.7800   693889.0  473.6179
# 3           472.77    472.480     472.6900   404264.0  472.6133
# 4           472.78    472.550     472.6700   250698.0  472.6734
# ...            ...        ...          ...        ...       ...
# 112994      583.38    583.080     583.1900   531037.0  583.2175
# 112995      583.42    582.800     583.3300   694988.0  583.1694
# 112996      583.61    583.115     583.5700   829842.0  584.9927
# 112997      584.11    583.200     583.9700  2382661.0  585.3033
# 112998      584.50    583.770     584.3600   270562.0  584.0794
#
#             timestamp  transactions  otc              timestamp_utc  \
# 0       1704205800000         11700  NaN  2024-01-02 14:30:00+00:00
# 1       1704205860000          3810  NaN  2024-01-02 14:31:00+00:00
# 2       1704205920000          3807  NaN  2024-01-02 14:32:00+00:00
# 3       1704205980000          3280  NaN  2024-01-02 14:33:00+00:00
# 4       1704206040000          2284  NaN  2024-01-02 14:34:00+00:00
# ...               ...           ...  ...                        ...
# 112994  1741035360000          5290  NaN  2025-03-03 20:56:00+00:00
# 112995  1741035420000          6733  NaN  2025-03-03 20:57:00+00:00
# 112996  1741035480000          6584  NaN  2025-03-03 20:58:00+00:00
# 112997  1741035540000         12913  NaN  2025-03-03 20:59:00+00:00
# 112998  1741035600000          1162  NaN  2025-03-03 21:00:00+00:00
#
#                     timestamp_est        date  years_to_maturity
# 0       2024-01-02 09:30:00-05:00  2024-01-02           0.000772
# 1       2024-01-02 09:31:00-05:00  2024-01-02           0.000770
# 2       2024-01-02 09:32:00-05:00  2024-01-02           0.000768
# 3       2024-01-02 09:33:00-05:00  2024-01-02           0.000766
# 4       2024-01-02 09:34:00-05:00  2024-01-02           0.000764
# ...                           ...         ...                ...
# 112994  2025-03-03 15:56:00-05:00  2025-03-03           0.000038
# 112995  2025-03-03 15:57:00-05:00  2025-03-03           0.000036
# 112996  2025-03-03 15:58:00-05:00  2025-03-03           0.000034
# 112997  2025-03-03 15:59:00-05:00  2025-03-03           0.000032
# 112998  2025-03-03 16:00:00-05:00  2025-03-03           0.000030
#
# [112999 rows x 20 columns]

# %%
env = SimEnv(df)

def compute_daily_atm_straddle_prices(df):
    """
    Compute straddle prices for a range of strikes.
    
    Parameters:
        spot (float): Spot price.
        atm_vol (float): At-the-money
        slope (float): Slope of the linear term.
        quadratic_term (float): Coefficient of the quadratic term.
        texp_years (float): Time to expiration in years.    

    Returns:
        array-like: Fitted volatilities for a range of strikes.
    """
    texp = df['years_to_maturity']
    spot = df['implied_spot']
    texp = df['years_to_maturity']
    vol=df['atm_vol']
    #print("variable sizes: ",texp.shape,spot.shape,vol.shape)
    straddle_prices = env.price_instrument('c', spot, spot, texp, vol) + env.price_instrument('p', spot, spot, texp, vol)

    return straddle_prices

straddle_prices_prices=compute_daily_atm_straddle_prices(df)

# %%
from copy import deepcopy
df2=deepcopy(df)
df2['straddle_prices']=straddle_prices_prices
bad_straddles=df2[df2['straddle_prices']<=0.000000001]

# %%
bad_straddles
# Out:
# Empty DataFrame
# Columns: [minute, implied_spot, atm_vol, slope, quadratic_term, scaled_slope, scaled_quadratic, open_price, high_price, low_price, close_price, volume, vwap, timestamp, transactions, otc, timestamp_utc, timestamp_est, date, years_to_maturity, straddle_prices]
# Index: []
#
# [0 rows x 21 columns]

# %%
def apply_quadratic_volatility_model(strikes, spot, atm_vol, slope, quadratic_term, texp_years):
    """
    Apply the quadratic volatility model to new data points.
    
    Parameters:
        strikes (array-like): Array of strike prices.
        spot (float): Spot price.
        atm_vol (float): At-the-money volatility.
        slope (float): Slope of the linear term.
        quadratic_term (float): Coefficient of the quadratic term.
        texp_years (float): Time to expiration in years.
    
    Returns:
        array-like: Fitted volatilities for the given strikes.
    """
    #print(f"apply_quadratic_vol input sizes: strikes={strikes}, spot={len(spot)}, atm_vol={len(atm_vol)}, slope={len(slope)}, quadratic_term={len(quadratic_term)}, texp_years={len(texp_years)}")
    log_strikes = np.log(strikes) - np.log(spot)
    fitted_vols = atm_vol + slope * log_strikes + quadratic_term * log_strikes**2
    #fitted_vols = atm_vol + (slope / np.sqrt(texp_years)) * log_strikes + quadratic_term * log_strikes**2
    fitted_vols= np.clip(fitted_vols, .05,.4)
    return fitted_vols

# %%
import py_vollib_vectorized
from copy import deepcopy
class sim_env:
    def __init__(self, df):
        # 📌 Market Data
        self.df = df  # Full dataset
        self.df_today = None  # Subset for the episode

        # 📌 Index Tracking
        self.global_index = 0  # Tracks position in full dataset
        self.daily_index = 0  # Tracks position within today's data
        self.start_index = 0  # Stores start index for the episode
        self.max_steps = 180  # Maximum number of steps in an episode

        # 📌 Trading Variables
        self.position = 0  # Straddle position
        self.entry_price = 0  # Price when position was opened
        self.position_open_time = None  # Time step when position was opened

        # 📌 Capital & PnL
        self.capital = 100
        self.pnl = 0
        self.position_value = 0

        # 📌 Episode State
        self.done = False
        self.current_time = None
        self.current_row = None

        # 📌 Actions & Observations
        self.action_space = [0, 1, 2]  # 0: Hold, 1: Open, 2: Close
        self.observation_space = self.df.columns
        self.observation_space=11
        self.debug=True


    """
    def select_todays_data(self):
        self.df_today = self.df[self.df['date'] == self.current_row['date']]
        self.df_today=deepcopy(self.df_today)

        return self.df_today

    """

    def update_time_step(self, minutes=1):
        self.global_index = min(self.global_index + minutes, len(self.df) - 1)
        self.daily_index = min(self.daily_index + minutes, len(self.df_today) - 1) 

    def get_current_time(self):
        return self.df.iloc[self.global_index]['minute']
    

    def get_current_row(self):
        return self.df.iloc[self.global_index]
    
    
    
    def reset(self):
        self.global_index = 0
        self.done = False
        self.position = 0

        # Pick a valid starting point
        self.start_index = self.pick_episode_start()
        self.global_index = self.start_index

        # Select today's data and set the daily index
        self.daily_index = self.df_today.index.get_loc(self.global_index)

        straddle_prices=self.compute_daily_atm_straddle_prices()

        self.df_today["daily_straddle_prices"]=straddle_prices
        self.df_today["open_straddle_pnl"]=0
        #self.current_time = self.current_row['minute']
        self.last_pnl=0


        return self.current_row

    """
    def _get_state(self):
        state = {
            'position': self.position,
            'capital': self.capital,
            'entry_price': self.entry_price,
            'position_value': self.position_value,
            'pnl': self.pnl
        }
        return state
    """
    def _get_state(self):
        """Returns the current state of the environment as a dictionary."""
        
        current_row = self.get_current_row()  # Get the current row based on global_index
        steps_taken=self.global_index-self.start_index
        steps_remaining=self.max_steps-steps_taken
        #steps_remaining = len(self.df_today) - self.global_index  # Remaining steps in today's episode
        time_to_expiration = current_row['years_to_maturity']
        
        # Position-related details
        position_status = "Open" if self.position > 0 else "Closed"
        position_strike = self.strike if self.position > 0 else None
        current_straddle_price = self.compute_straddle_prices(position_strike) if self.position > 0 else None
        spot_vol = self.compute_spot_vols(position_strike) if self.position > 0 else None
        
        # Market data
        state = {
            "current_time": current_row['minute'],  # Current datetime
            "episode_step": steps_taken,  # How far we are in the episode
            "steps_remaining": steps_remaining,  # Remaining steps
            "time_to_expiration": time_to_expiration,  # Time to expiration

            # Market & volatility data
            "current_spot": current_row['implied_spot'],
            "current_atm_vol": current_row['atm_vol'],
            "current_scaled_slope": current_row['scaled_slope'],  # Scaled slope
            "current_scaled_quadratic": current_row['scaled_quadratic'],  # Scaled quadratic
            #"spot_vol_for_straddle": spot_vol,  # Spot vol specifically for the straddle

            
            # Position & trading details
            "position_status": position_status,
            "position_strike": position_strike,
            "current_straddle_price": self.df_today["daily_straddle_prices"].loc[(self.global_index)],

            # PnL Tracking
            "cumulative_pnl": self.df_today["open_straddle_pnl"].loc[self.global_index],
            "last_step_pnl": self.last_pnl
            }
        
        return state 
    
    def pick_random_day(self, burn_days=5):
        all_days = self.df['date'].unique()
        all_days = sorted(all_days)
        start_day = np.random.choice(all_days[burn_days:-1])
        return start_day

    def pick_random_timestep(self,df):
        all_times = self.df['minute'].apply(lambda x: x.time()).unique()
        all_times = sorted(all_times)
        latest_time = pd.Timestamp('12:45').time()
        earliest_time = pd.Timestamp('9:30').time()
        all_times = [x for x in all_times if x >= earliest_time and x <= latest_time]
        start_time = np.random.choice(all_times)
        return start_time

    def pick_episode_start(self):
        start_day = self.pick_random_day()
        self.df_today = self.df[self.df['date'] == start_day]
        self.df_today=deepcopy(self.df_today)
        start_time=self.pick_random_timestep(self.df_today)
        episode_start_index = self.df[(self.df['date'] == start_day) & (self.df['minute'].apply(lambda x: x.time()) == start_time)].index[0]
        
        #self.current_row = self.df.iloc[self.global_index]
        #self.df_today=self.select_todays_data()
        return episode_start_index
    
    

    
    def compute_spot_vols(self,strike):
        """
        Compute fitted volatilities for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        spots=self.df_today['implied_spot']
        atm_vol=self.df_today['atm_vol']
        texp_years = self.df_today['years_to_maturity']
        slope=self.df_today['slope']
        quadratic_term=self.df_today['quadratic_term']
        #print(f"variable sizes: texp={texp_years.shape}, spot={spots.shape}, atm_vol={atm_vol.shape}, slope={slope.shape}, quadratic_term={quadratic_term.shape},strike={strike.shape}")
        vols = apply_quadratic_volatility_model(strike, spots, atm_vol, slope, quadratic_term, texp_years)
        #print(f"vols size={vols.shape}")
        return vols


    def compute_daily_atm_straddle_prices(self):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        texp = self.df_today['years_to_maturity']
        vol=self.df_today['atm_vol']
        #print("variable sizes: ",texp.shape,spot.shape,vol.shape)
        straddle_prices = self.price_instrument('c', spot, spot, texp, vol) + self.price_instrument('p', spot, spot, texp, vol)

        return straddle_prices

    
    def compute_straddle_prices(self, strike):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
    
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        vols=self.compute_spot_vols(strike)
        #print(f"variable sizes: texp={texp.shape}, spot={spot.shape}, vols={vols.shape}")
        #vols=apply_apply_quadratic_volatility_model(strike, spot, atm_vols, slopes, quadratic_terms, texp)
        straddle_prices = self.price_instrument('c', strike, spot, texp, vols) + self.price_instrument('p', strike, spot, texp, vols) 
        #print(f"straddle_prices={straddle_prices}")

        df_output=pd.DataFrame()
    
        df_output["spot"]=spot
        df_output["texp"]=texp
        df_output["vols"]=vols
        df_output["strike"]=strike
        df_output["straddle_prices"]=straddle_prices
        df_output.to_csv("straddle_prices.csv")

        return straddle_prices

    
    def update_time_step(self, minutes=1):
        self.global_index = min(self.global_index + minutes, self.df_today.index.max())


    def step(self, action):
        """
        Execute the selected action in the environment.
        """
        done = False
        reward = 0.0
        #print(f"action={action}")

        if action == 1:  # Open position
            if self.position == 0:  # Only open if no position
                self.open_position()
                self.position_open_time = self.global_index
                #print(f"current index={self.global_index}")
                self.update_time_step(60)
                #print(f"adjusted index={self.global_index}")

        elif action == 2:  # Close position
            if self.position > 0 and (self.global_index - self.position_open_time >= 60):
                pnl=self.df_today["open_straddle_pnl"].loc[self.global_index]
                reward=pnl-self.last_pnl
                self.last_pnl=pnl
            done = True  # End episode

        elif action == 3:  # Hold

            if self.position > 0:
                print("looking up pnl")
                pnl=self.df_today["open_straddle_pnl"].loc[self.global_index]
                reward=pnl-self.last_pnl
                self.last_pnl=pnl
    
            self.update_time_step(1)
            if self.global_index - self.start_index >= 180:
                done=True
            if self.position > 0 and self.global_index - self.position_open_time >= 120:
                done=True

        # Get next state
        next_state = self._get_state()
        return next_state, reward, done, {}
    
    def valid_actions(self):
        if self.position == 0:
            return [1, 3]
        else:
            return [2, 3]

    def price_instrument(self, cp, strike, spot, texp, vol):
        #if self.debug:
        #    print(f"cp={cp}\n, strike={strike}\n, spot={spot}\n, texp={texp}\n, vol={vol}\n")
        #print(f"pricing_insturment sizes: cp={cp}, strike={strike.shape}, spot={spot.shape}, texp={texp.shape}, vol={vol.shape}")
        return py_vollib_vectorized.models.vectorized_black_scholes(cp, spot, strike, texp, 0, vol,return_as="numpy")



    def open_position(self):

        ivol = self.get_current_row()['implied_spot']
        texp = self.get_current_row()['years_to_maturity']
        spot=self.get_current_row()['implied_spot']
        #straddle_price_1 = self.price_one_day_straddle(texp, ivol)
        straddle_price=self.df_today['daily_straddle_prices'].loc[self.global_index]
        #print(f"straddle_price={straddle_price}")
        #print(f"straddle_price_1={straddle_price_1}")
        if (straddle_price == 0):
            print(f"eror: straddle_price={straddle_price}. at time={self.get_current_time()}")
        self.position = self.capital / straddle_price
        #self.position_value = self.position * straddle_price
        self.strike=spot
        #spot_vols=self.compute_spot_vols(self.strike)
        self.straddle_prices=self.compute_straddle_prices(self.strike)
        self.df_today["open_straddle_prices"]=self.straddle_prices
        self.df_today["open_straddle_pnl"]=(self.df_today["open_straddle_prices"]- straddle_price)*self.position
        self.position_open_time = self.global_index
        return self.position_value


env = sim_env(df)
env.reset()
#env.current_time[0]
for i in range(2):  
    row=env.pick_episode_start()
    current_time = env.get_current_time()
    if current_time.time() < pd.Timestamp('9:30').time():
        print('error')
    if current_time.time() > pd.Timestamp('12:45').time():
        print('error')
env.reset()
#env.price_one_day_straddle(0.5, 0.2)
#pos_value = env.open_position(1)
#env.position_value
env.df_today
strike=env.df_today['implied_spot'].iloc[0]
vols=env.compute_spot_vols(strike)
#straddle_prices=env.compute_straddle_prices(strike,vols)
from copy import deepcopy
df_episode=deepcopy(env.df_today)

df_episode.reset_index(inplace=True)
env.global_index
env.df_today
env.global_index

#env.open_position()
#print (f"current index={env.global_index}")
(s, reward, done,bla)=env.step(1)
print(f"s={s}")
(s,reward,done,bla)=env.step(3)
print(f"s={s}")
(s,reward,done,bla)=env.step(3)
print(f"s={s}")
(s,reward,done,bla)=env.step(2)
print(f"s={s}")
#print (f"current index={env.global_index}")
# Out:
# s={'current_time': Timestamp('2024-03-15 13:34:00-0400', tz='UTC-04:00'), 'episode_step': np.int64(60), 'steps_remaining': np.int64(120), 'time_to_expiration': np.float64(0.0003099094988212031), 'current_spot': np.float64(509.328899869032), 'current_atm_vol': np.float64(0.255969101721919), 'current_scaled_slope': np.float64(-0.0010416386851202), 'current_scaled_quadratic': np.float64(0.1543470315612079), 'position_status': 'Open', 'position_strike': np.float64(509.39728585120406), 'current_straddle_price': np.float64(1.8312304509779438), 'cumulative_pnl': np.float64(-11.305304379558237), 'last_step_pnl': 0}
# looking up pnl
# s={'current_time': Timestamp('2024-03-15 13:35:00-0400', tz='UTC-04:00'), 'episode_step': np.int64(61), 'steps_remaining': np.int64(119), 'time_to_expiration': np.float64(0.0003080082135523614), 'current_spot': np.float64(509.278777036479), 'current_atm_vol': np.float64(0.2576939951475856), 'current_scaled_slope': np.float64(-0.0011649728622523), 'current_scaled_quadratic': np.float64(0.1502140368461493), 'position_status': 'Open', 'position_strike': np.float64(509.39728585120406), 'current_straddle_price': np.float64(1.8377258203763416), 'cumulative_pnl': np.float64(-10.927744826313104), 'last_step_pnl': np.float64(-11.305304379558237)}
# looking up pnl
# s={'current_time': Timestamp('2024-03-15 13:36:00-0400', tz='UTC-04:00'), 'episode_step': np.int64(62), 'steps_remaining': np.int64(118), 'time_to_expiration': np.float64(0.00030610692828351966), 'current_spot': np.float64(509.3615426871137), 'current_atm_vol': np.float64(0.2537220119504094), 'current_scaled_slope': np.float64(-0.0010623754670698), 'current_scaled_quadratic': np.float64(0.166360162747361), 'position_status': 'Open', 'position_strike': np.float64(509.39728585120406), 'current_straddle_price': np.float64(1.8040999037409267), 'cumulative_pnl': np.float64(-12.639726957443042), 'last_step_pnl': np.float64(-10.927744826313104)}
# s={'current_time': Timestamp('2024-03-15 13:36:00-0400', tz='UTC-04:00'), 'episode_step': np.int64(62), 'steps_remaining': np.int64(118), 'time_to_expiration': np.float64(0.00030610692828351966), 'current_spot': np.float64(509.3615426871137), 'current_atm_vol': np.float64(0.2537220119504094), 'current_scaled_slope': np.float64(-0.0010623754670698), 'current_scaled_quadratic': np.float64(0.166360162747361), 'position_status': 'Open', 'position_strike': np.float64(509.39728585120406), 'current_straddle_price': np.float64(1.8040999037409267), 'cumulative_pnl': np.float64(-12.639726957443042), 'last_step_pnl': np.float64(-12.639726957443042)}

# %%
env = sim_env(df)
env.reset()
states=[]
rewards=[]
done_arr=[]
for i in range(1,60):
    (s, reward, done,bla)=env.step(3)
    states.append(s)
    rewards.append(reward)
    done_arr.append(done)
    if done:
        print (f"done at {i}, reward={reward}")
        break
(s,reward,done,bla)=env.step(1)
print(f"s={s}")
for i in range(1,80):
    (s, reward, done,bla)=env.step(3)
    states.append(s)
    rewards.append(reward)
    done_arr.append(done)
    if done:
        print (f"done at {i}, reward={reward}")
        break
# Out:
# s={'current_time': Timestamp('2024-04-10 12:35:00-0400', tz='UTC-04:00'), 'episode_step': np.int64(119), 'steps_remaining': np.int64(61), 'time_to_expiration': np.float64(0.00042208532968286564), 'current_spot': np.float64(513.3988212512414), 'current_atm_vol': np.float64(0.2925073469593534), 'current_scaled_slope': np.float64(-0.0011325089945451), 'current_scaled_quadratic': np.float64(0.0933987906278003), 'position_status': 'Open', 'position_strike': np.float64(514.0043419847328), 'current_straddle_price': np.float64(2.4616776513510596), 'cumulative_pnl': np.float64(-4.2887912429423105), 'last_step_pnl': 0}
# done at 60, reward=5.215361022862181

# %%
env.global_index
env.start_index
print(f"env.global_index={env.global_index}, env.start_index={env.start_index}")
# Out:
# env.global_index=26832, env.start_index=26653

# %%
# Out:
# {'current_time': Timestamp('2024-04-10 13:35:00-0400', tz='UTC-04:00'),
#  'episode_step': np.int64(179),
#  'steps_remaining': np.int64(1),
#  'time_to_expiration': np.float64(0.0003080082135523614),
#  'current_spot': np.float64(513.3157213930348),
#  'current_atm_vol': np.float64(0.3802153111164066),
#  'current_scaled_slope': np.float64(-0.0058110987633437),
#  'current_scaled_quadratic': np.float64(0.0513711878271153),
#  'position_status': 'Open',
#  'position_strike': np.float64(514.0043419847328),
#  'current_straddle_price': np.float64(2.7329681601807208),
#  'cumulative_pnl': np.float64(5.372098314619221),
#  'last_step_pnl': np.float64(9.30094508360665)}

# %%
env.global_index
env.start_index
env.position

env.df_today[["minute","open_straddle_prices","implied_spot","open_straddle_pnl","atm_vol","years_to_maturity"]].loc[env.global_index+180-5:env.global_index+180+5]
# Out:
#                           minute  open_straddle_prices  implied_spot  \
# 64764  2024-08-29 13:40:00-04:00              2.811932    562.346557
# 64765  2024-08-29 13:41:00-04:00              2.841352    562.380443
# 64766  2024-08-29 13:42:00-04:00              2.857430    562.383986
# 64767  2024-08-29 13:43:00-04:00              3.036799    562.615328
# 64768  2024-08-29 13:44:00-04:00              3.001344    562.582314
# 64769  2024-08-29 13:45:00-04:00              2.994486    562.592433
# 64770  2024-08-29 13:46:00-04:00              2.870171    562.440000
# 64771  2024-08-29 13:47:00-04:00              2.779249    562.325410
# 64772  2024-08-29 13:48:00-04:00              2.769865    562.289644
# 64773  2024-08-29 13:49:00-04:00              2.597649    562.064089
# 64774  2024-08-29 13:50:00-04:00              2.693597    562.193953
#
#        open_straddle_pnl   atm_vol  years_to_maturity
# 64764         -10.918230  0.198839           0.000299
# 64765          -9.986186  0.199443           0.000297
# 64766          -9.476833  0.200358           0.000295
# 64767          -3.794447  0.196196           0.000293
# 64768          -4.917648  0.196249           0.000291
# 64769          -5.134938  0.193650           0.000289
# 64770          -9.073214  0.194565           0.000287
# 64771         -11.953604  0.197931           0.000285
# 64772         -12.250886  0.201454           0.000283
# 64773         -17.706690  0.204082           0.000281
# 64774         -14.667066  0.200210           0.000279

# %%
env.df_today[["minute","open_straddle_prices","implied_spot","open_straddle_pnl","atm_vol","years_to_maturity"]].loc[env.start_index-5:env.start_index+5]
# Out:
#                           minute  open_straddle_prices  implied_spot  \
# 64522  2024-08-29 09:38:00-04:00              3.278798    560.546692
# 64523  2024-08-29 09:39:00-04:00              3.223714    560.394307
# 64524  2024-08-29 09:40:00-04:00              3.171848    560.182034
# 64525  2024-08-29 09:41:00-04:00              3.178415    560.353155
# 64526  2024-08-29 09:42:00-04:00              3.178438    559.882659
# 64527  2024-08-29 09:43:00-04:00              3.156574    559.826810
# 64528  2024-08-29 09:44:00-04:00              3.149820    559.867711
# 64529  2024-08-29 09:45:00-04:00              3.152868    559.705579
# 64530  2024-08-29 09:46:00-04:00              3.121236    559.916124
# 64531  2024-08-29 09:47:00-04:00              3.060952    559.743085
# 64532  2024-08-29 09:48:00-04:00              3.047603    560.140000
#
#        open_straddle_pnl   atm_vol  years_to_maturity
# 64522           3.872059  0.258312           0.000759
# 64523           2.126997  0.256640           0.000757
# 64524           0.483877  0.255581           0.000755
# 64525           0.691936  0.254223           0.000753
# 64526           0.692650  0.259354           0.000751
# 64527           0.000000  0.258197           0.000749
# 64528          -0.213970  0.257733           0.000747
# 64529          -0.117403  0.259088           0.000745
# 64530          -1.119498  0.255694           0.000743
# 64531          -3.029297  0.252041           0.000742
# 64532          -3.452198  0.248232           0.000740

# %%
# Replace zero implied_spot with NaN to use forward fill
from copy import deepcopy
df = deepcopy(env.df_today)
# Replace zero implied_spot with NaN to use forward fill
df.loc[df['implied_spot'] == 0, ['implied_spot', 'atm_vol', 'slope', 'quadratic_term', 'scaled_slope', 'scaled_quadratic']] = np.nan

# Forward fill the NaN values
df.ffill().infer_objects(copy=False)
#df=df.fillna(method='ffill')

# Verify the changes
df
# Out:
# /var/folders/c1/dv7w7b2x49j3spqsxnz6y_sw0000gn/T/ipykernel_66485/1879655896.py:8: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.ffill().infer_objects(copy=False)
#                           minute  implied_spot   atm_vol     slope  \
# 68425  2024-09-13 09:31:00-04:00    559.566973  0.272952 -4.160087
# 68426  2024-09-13 09:32:00-04:00    559.644417  0.276763 -4.334088
# 68427  2024-09-13 09:33:00-04:00    560.032755  0.273159 -4.387338
# 68428  2024-09-13 09:34:00-04:00    560.242289  0.270957 -4.489120
# 68429  2024-09-13 09:35:00-04:00    560.305233  0.273457 -4.570107
# ...                          ...           ...       ...       ...
# 68811  2024-09-13 15:57:00-04:00    562.055358  0.224733 -7.518302
# 68812  2024-09-13 15:58:00-04:00    562.046960  0.224867  0.373759
# 68813  2024-09-13 15:59:00-04:00    562.055645  0.206430 -0.122318
# 68814  2024-09-13 16:00:00-04:00    561.918966  0.204025 -9.529928
# 68815  2024-09-13 16:01:00-04:00    561.827405  0.085863  3.874362
#
#        quadratic_term  scaled_slope  scaled_quadratic  open_price  high_price  \
# 68425      170.192417     -0.011558          0.131375      559.71    559.7900
# 68426      181.344065     -0.012027          0.139639      559.56    559.8900
# 68427      171.509566     -0.012159          0.131740      559.69    560.2400
# 68428      169.453073     -0.012426          0.129838      560.05    560.2892
# 68429      156.760224     -0.012635          0.119814      560.28    560.3600
# ...               ...           ...               ...         ...         ...
# 68811     4421.900846     -0.004636          0.168146      562.18    562.2000
# 68812     4070.268170      0.000225          0.147036      562.06    562.0900
# 68813     5265.629496     -0.000072          0.180206      562.07    562.1600
# 68814     5973.337390     -0.005418          0.193069      562.02    562.0500
# 68815     7422.945583      0.002137          0.225810      561.95    562.0100
#
#        low_price  ...      timestamp  transactions  otc  \
# 68425   559.4500  ...  1726234200000          4292  NaN
# 68426   559.5500  ...  1726234260000          3138  NaN
# 68427   559.6900  ...  1726234320000          2344  NaN
# 68428   560.0100  ...  1726234380000          1393  NaN
# 68429   560.1900  ...  1726234440000          1565  NaN
# ...          ...  ...            ...           ...  ...
# 68811   562.0200  ...  1726257360000          2192  NaN
# 68812   561.7702  ...  1726257420000          2465  NaN
# 68813   561.9650  ...  1726257480000          3634  NaN
# 68814   561.7900  ...  1726257540000          6573  NaN
# 68815   561.7700  ...  1726257600000           806  NaN
#
#                    timestamp_utc              timestamp_est        date  \
# 68425  2024-09-13 13:30:00+00:00  2024-09-13 09:30:00-04:00  2024-09-13
# 68426  2024-09-13 13:31:00+00:00  2024-09-13 09:31:00-04:00  2024-09-13
# 68427  2024-09-13 13:32:00+00:00  2024-09-13 09:32:00-04:00  2024-09-13
# 68428  2024-09-13 13:33:00+00:00  2024-09-13 09:33:00-04:00  2024-09-13
# 68429  2024-09-13 13:34:00+00:00  2024-09-13 09:34:00-04:00  2024-09-13
# ...                          ...                        ...         ...
# 68811  2024-09-13 19:56:00+00:00  2024-09-13 15:56:00-04:00  2024-09-13
# 68812  2024-09-13 19:57:00+00:00  2024-09-13 15:57:00-04:00  2024-09-13
# 68813  2024-09-13 19:58:00+00:00  2024-09-13 15:58:00-04:00  2024-09-13
# 68814  2024-09-13 19:59:00+00:00  2024-09-13 15:59:00-04:00  2024-09-13
# 68815  2024-09-13 20:00:00+00:00  2024-09-13 16:00:00-04:00  2024-09-13
#
#       years_to_maturity daily_straddle_prices open_straddle_pnl  \
# 68425          0.000772              3.385819         76.564723
# 68426          0.000770              3.429337         77.120202
# 68427          0.000768              3.382851         70.168763
# 68428          0.000766              3.352673         66.703286
# 68429          0.000764              3.379793         67.367815
# ...                 ...                   ...               ...
# 68811          0.000038              0.621476        -60.419714
# 68812          0.000036              0.606093        -62.125465
# 68813          0.000034              0.541568        -64.075110
# 68814          0.000032              0.520050        -67.944566
# 68815          0.000030              0.212292        -82.011332
#
#        open_straddle_prices
# 68425              3.594954
# 68426              3.606264
# 68427              3.464729
# 68428              3.394170
# 68429              3.407700
# ...                     ...
# 68811              0.805876
# 68812              0.771146
# 68813              0.731450
# 68814              0.652666
# 68815              0.366259
#
# [391 rows x 23 columns]

# %%
import gymnasium as gym  # ✅ Use gymnasium instead of gym
import numpy as np
import pandas as pd
from gymnasium import spaces

class SimEnv(gym.Env):
    """
    Custom Options Trading Environment for Reinforcement Learning.
    """
    def __init__(self, df):
        super(SimEnv, self).__init__()
        
        # Market Data
        self.df = df
        self.df_today = None
        
        # Index Tracking
        self.global_index = 0
        self.daily_index = 0
        self.start_index = 0
        self.max_steps = 62  # Max steps per episode

        # Trading Variables
        self.position = 0
        self.entry_price = 0
        self.position_open_time = None

        # Capital & PnL
        self.capital = 100
        self.pnl = 0
        self.position_value = 0

        # Episode State
        self.done = False
        self.current_row = None

        # Action & Observation Space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Open, 2: Close
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(11,), dtype=np.float32)

    def reset(self,seed=None):
        """ Reset environment and start a new episode. """
        self.global_index = self.pick_episode_start()
        self.daily_index = self.df_today.index.get_loc(self.global_index)
        self.start_index = self.global_index
        self.done = False
        self.position = 0
        self.pnl = 0

        # Compute daily straddle prices before trading starts
        straddle_prices = self.compute_daily_atm_straddle_prices()
        self.df_today["daily_straddle_prices"] = straddle_prices
        self.df_today["open_straddle_pnl"] = 0

        obs = self._get_state()  # Observation (state)
        info = {}  # Additional info (can be empty)

        return obs, info  # ✅ Must return a tuple (obs, info)

    def _get_state(self):
        """ Returns the current state as a NumPy array. """
        row = self.df.iloc[self.global_index]
        steps_taken = self.global_index - self.start_index
        steps_remaining = self.max_steps - steps_taken
        
        state = np.array([
            row['implied_spot'],  # Current spot price
            row['atm_vol'],  # ATM implied volatility
            row['scaled_slope'],  # Volatility skew slope
            row['scaled_quadratic'],  # Volatility skew curvature
            steps_taken,  # How many steps taken in this episode
            steps_remaining,  # Steps remaining before timeout
            self.position,  # Position status (0: no position, >0: position held)
            int(self.position>0),  # binary state to make it sumpler
            self.pnl,  # Cumulative PnL
            self.df_today["daily_straddle_prices"].loc[self.global_index],  # Current straddle price
            self.df_today["open_straddle_pnl"].loc[self.global_index]  # PnL from position
        ], dtype=np.float32)

        return state

    def pick_random_day(self, burn_days=5):
        all_days = self.df['date'].unique()
        all_days = sorted(all_days)
        #print(f"all_days={all_days}")
        start_day = np.random.choice(all_days[burn_days:-1])
        return start_day

    def pick_random_timestep(self,df):
        all_times = df['minute'].apply(lambda x: x.time()).unique()
        all_times = sorted(all_times)
        latest_time = pd.Timestamp('12:45').time()
        earliest_time = pd.Timestamp('9:30').time()
        all_times = [x for x in all_times if x >= earliest_time and x <= latest_time]
        #print(f"all_times={all_times}")
        start_time = np.random.choice(all_times)
        return start_time

    def pick_episode_start(self):
        start_day = self.pick_random_day()
        self.df_today = self.df[self.df['date'] == start_day]
        self.df_today=deepcopy(self.df_today)
        start_time=self.pick_random_timestep(self.df_today)
        episode_start_index = self.df_today [(self.df_today['minute'].apply(lambda x: x.time()) == start_time)].index[0]
        #print(f"episode_start_index={episode_start_index}")
        
        #self.current_row = self.df.iloc[self.global_index]
        #self.df_today=self.select_todays_data()
        return episode_start_index
    
    

    
    def compute_spot_vols(self,strike):
        """
        Compute fitted volatilities for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        spots=self.df_today['implied_spot']
        atm_vol=self.df_today['atm_vol']
        texp_years = self.df_today['years_to_maturity']
        slope=self.df_today['slope']
        quadratic_term=self.df_today['quadratic_term']
        #print(f"variable sizes: texp={texp_years.shape}, spot={spots.shape}, atm_vol={atm_vol.shape}, slope={slope.shape}, quadratic_term={quadratic_term.shape},strike={strike.shape}")
        vols = apply_quadratic_volatility_model(strike, spots, atm_vol, slope, quadratic_term, texp_years)
        #print(f"vols size={vols.shape}")
        return vols


    def compute_daily_atm_straddle_prices(self):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        texp = self.df_today['years_to_maturity']
        vol=self.df_today['atm_vol']
        #print("variable sizes: ",texp.shape,spot.shape,vol.shape)
        straddle_prices = self.price_instrument('c', spot, spot, texp, vol) + self.price_instrument('p', spot, spot, texp, vol)

        return straddle_prices

    
    def compute_straddle_prices(self, strike):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
    
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        vols=self.compute_spot_vols(strike)
        #print(f"variable sizes: texp={texp.shape}, spot={spot.shape}, vols={vols.shape}")
        #vols=apply_apply_quadratic_volatility_model(strike, spot, atm_vols, slopes, quadratic_terms, texp)
        straddle_prices = self.price_instrument('c', strike, spot, texp, vols) + self.price_instrument('p', strike, spot, texp, vols) 
        #print(f"straddle_prices={straddle_prices}")

        df_output=pd.DataFrame()
    
        df_output["spot"]=spot
        df_output["texp"]=texp
        df_output["vols"]=vols
        df_output["strike"]=strike
        df_output["straddle_prices"]=straddle_prices
        df_output.to_csv("straddle_prices.csv")

        return straddle_prices

    
    def update_time_step(self, minutes=1):
        self.global_index = min(self.global_index + minutes, self.df_today.index.max())

    def step(self, action):
        """ Execute the selected action. """
        reward = 0.0
        #print (f"self.done={self.done},action={action}")
        allowed_actions = self.valid_actions()

        if action not in allowed_actions:
            reward = -1000  # Strong penalty for invalid action
            truncated=True
            self.done=True
            return self._get_state(), reward, self.done, truncated, {}

        if action == 1 and self.position == 0:  # Open position
            #print("opening_position")
            self.open_position()
            self.update_time_step(60)

        elif action == 2 and self.position > 0:  # Close position
            reward = self.df_today["open_straddle_pnl"].loc[self.global_index] - self.pnl
            self.pnl = self.df_today["open_straddle_pnl"].loc[self.global_index]
            self.position = 0
            self.done = True

        elif action == 3:  # Hold position
            if self.position > 0:
                reward = self.df_today["open_straddle_pnl"].loc[self.global_index] - self.pnl
                self.pnl = self.df_today["open_straddle_pnl"].loc[self.global_index]
            
            self.update_time_step(1)

        # End episode if time exceeds max steps
        if self.global_index - self.start_index >= self.max_steps:
            #print("self.global_index - self.start_index >= self.max_steps")
            self.done = True

        return self._get_state(), reward, self.done, False,{}
    
    def valid_actions(self):
        if self.position == 0:
            return [1, 3]
        else:
            return [2, 3]


    def render(self, mode="human"):
        """ Optional: Print state information for debugging. """
        print(f"Time: {self.df.iloc[self.global_index]['minute']}, Position: {self.position}, PnL: {self.pnl}")

    def close(self):
        pass


    def valid_actionsa(self):
        if self.position == 0:
            return [1, 3]
        else:
            return [2, 3]

    def price_instrument(self, cp, strike, spot, texp, vol):
        #if self.debug:
        #    print(f"cp={cp}\n, strike={strike}\n, spot={spot}\n, texp={texp}\n, vol={vol}\n")
        #print(f"pricing_insturment sizes: cp={cp}, strike={strike.shape}, spot={spot.shape}, texp={texp.shape}, vol={vol.shape}")
        return py_vollib_vectorized.models.vectorized_black_scholes(cp, spot, strike, texp, 0, vol,return_as="numpy")



    
    def pick_random_day(self, burn_days=5):
        all_days = self.df['date'].unique()
        all_days = sorted(all_days)
        start_day = np.random.choice(all_days[burn_days:-1])
        return start_day

    def pick_random_timestep(self,df):
        all_times = self.df['minute'].apply(lambda x: x.time()).unique()
        all_times = sorted(all_times)
        latest_time = pd.Timestamp('12:45').time()
        earliest_time = pd.Timestamp('9:30').time()
        all_times = [x for x in all_times if x >= earliest_time and x <= latest_time]
        start_time = np.random.choice(all_times)
        return start_time

    def pick_episode_start(self):
        start_day = self.pick_random_day()
        self.df_today = self.df[self.df['date'] == start_day]
        self.df_today=deepcopy(self.df_today)
        start_time=self.pick_random_timestep(self.df_today)
        episode_start_index = self.df[(self.df['date'] == start_day) & (self.df['minute'].apply(lambda x: x.time()) == start_time)].index[0]
        
        #self.current_row = self.df.iloc[self.global_index]
        #self.df_today=self.select_todays_data()
        return episode_start_index
    
    

    
    def compute_spot_vols(self,strike):
        """
        Compute fitted volatilities for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        spots=self.df_today['implied_spot']
        atm_vol=self.df_today['atm_vol']
        texp_years = self.df_today['years_to_maturity']
        slope=self.df_today['slope']
        quadratic_term=self.df_today['quadratic_term']
        #print(f"variable sizes: texp={texp_years.shape}, spot={spots.shape}, atm_vol={atm_vol.shape}, slope={slope.shape}, quadratic_term={quadratic_term.shape},strike={strike.shape}")
        vols = apply_quadratic_volatility_model(strike, spots, atm_vol, slope, quadratic_term, texp_years)
        #print(f"vols size={vols.shape}")
        return vols


    def compute_daily_atm_straddle_prices(self):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        texp = self.df_today['years_to_maturity']
        vol=self.df_today['atm_vol']
        #print("variable sizes: ",texp.shape,spot.shape,vol.shape)
        straddle_prices = self.price_instrument('c', spot, spot, texp, vol) + self.price_instrument('p', spot, spot, texp, vol)

        return straddle_prices

    
    def compute_straddle_prices(self, strike):
        """
        Compute straddle prices for a range of strikes.
        
        Parameters:
            spot (float): Spot price.
            atm_vol (float): At-the-money
            slope (float): Slope of the linear term.
            quadratic_term (float): Coefficient of the quadratic term.
            texp_years (float): Time to expiration in years.    

        Returns:
            array-like: Fitted volatilities for a range of strikes.
        """
    
        texp = self.df_today['years_to_maturity']
        spot = self.df_today['implied_spot']
        vols=self.compute_spot_vols(strike)
        #print(f"variable sizes: texp={texp.shape}, spot={spot.shape}, vols={vols.shape}")
        #vols=apply_apply_quadratic_volatility_model(strike, spot, atm_vols, slopes, quadratic_terms, texp)
        straddle_prices = self.price_instrument('c', strike, spot, texp, vols) + self.price_instrument('p', strike, spot, texp, vols) 
        #print(f"straddle_prices={straddle_prices}")

        df_output=pd.DataFrame()
    
        df_output["spot"]=spot
        df_output["texp"]=texp
        df_output["vols"]=vols
        df_output["strike"]=strike
        df_output["straddle_prices"]=straddle_prices
        df_output.to_csv("straddle_prices.csv")

        return straddle_prices


    def update_time_step(self, minutes=1):
        self.global_index = min(self.global_index + minutes, self.df_today.index.max())

    def price_instrument(self, cp, strike, spot, texp, vol):
        #if self.debug:
        #    print(f"cp={cp}\n, strike={strike}\n, spot={spot}\n, texp={texp}\n, vol={vol}\n")
        #print(f"pricing_insturment sizes: cp={cp}, strike={strike.shape}, spot={spot.shape}, texp={texp.shape}, vol={vol.shape}")
        return py_vollib_vectorized.models.vectorized_black_scholes(cp, spot, strike, texp, 0, vol,return_as="numpy")

    def update_time_step(self, minutes=1):
        self.global_index = min(self.global_index + minutes, len(self.df) - 1)
        self.daily_index = min(self.daily_index + minutes, len(self.df_today) - 1) 

    def get_current_time(self):
        return self.df.iloc[self.global_index]['minute']
    

    def get_current_row(self):
        return self.df.iloc[self.global_index]

    def open_position(self):

        ivol = self.get_current_row()['implied_spot']
        texp = self.get_current_row()['years_to_maturity']
        spot=self.get_current_row()['implied_spot']
        #straddle_price_1 = self.price_one_day_straddle(texp, ivol)
        straddle_price=self.df_today['daily_straddle_prices'].loc[self.global_index]
        #print(f"straddle_price={straddle_price}")
        #print(f"straddle_price_1={straddle_price_1}")
        if (straddle_price == 0):
            print(f"eror: straddle_price={straddle_price}. at time={self.get_current_time()}")
        self.position = self.capital / straddle_price
        #self.position_value = self.position * straddle_price
        self.strike=spot
        #spot_vols=self.compute_spot_vols(self.strike)
        self.straddle_prices=self.compute_straddle_prices(self.strike)
        self.df_today["open_straddle_prices"]=self.straddle_prices
        self.df_today["open_straddle_pnl"]=(self.df_today["open_straddle_prices"]- straddle_price)*self.position
        self.position_open_time = self.global_index
        return self.position*straddle_price


    def _get_state(self):
        """ Returns the current state as a NumPy array. """
        row = self.df.iloc[self.global_index]
        steps_taken = self.global_index - self.start_index
        steps_remaining = self.max_steps - steps_taken
        
        state = np.array([
            row['implied_spot'],  # Current spot price
            row['atm_vol'],  # ATM implied volatility
            row['scaled_slope'],  # Volatility skew slope
            row['scaled_quadratic'],  # Volatility skew curvature
            steps_taken,  # How many steps taken in this episode
            steps_remaining,  # Steps remaining before timeout
            self.position,  # Position status (0: no position, >0: position held)
            int(self.position>0),  # binary state to make it sumpler
            self.pnl,  # Cumulative PnL
            self.df_today["daily_straddle_prices"].loc[self.global_index],  # Current straddle price
            self.df_today["open_straddle_pnl"].loc[self.global_index]  # PnL from position
        ], dtype=np.float32)

        return state

    def valid_actions(self):
        if self.position == 0:
            return [0, 2]
        else:
            return [1, 2]

    def render(self, mode="human"):
        """ Optional: Print state information for debugging. """
        print(f"Time: {self.df.iloc[self.global_index]['minute']}, Position: {self.position}, PnL: {self.pnl}")

    def close(self):
        pass

def get_valid_actions(observations):
    """ Returns a boolean mask indicating valid actions for a batch of states """
    valid_mask = np.ones((len(observations), env.action_space.n), dtype=bool)

    for i, obs in enumerate(observations):
        if obs[6] == 0:  # If no position is open
            valid_mask[i][2] = False  # Disallow "Close Position"
        else:
            valid_mask[i][1] = False  # Disallow "Open Position"

    return torch.tensor(valid_mask, dtype=torch.bool)

# %%
env=SimEnv(df)
env.reset()
# Out:
# (array([ 5.4603583e+02,  1.4560649e-01, -5.7404116e-03,  3.7413976e-01,
#          4.6683000e+04, -4.6503000e+04,  0.0000000e+00,  0.0000000e+00,
#          0.0000000e+00,  1.3885633e+00,  0.0000000e+00], dtype=float32),
#  {})

# %%
env.df_today.loc[env.global_index]
env.df_today.index[env.current_time[0]
env.current_time[0]
# Out:
#   Cell In[227], line 2
#     env.df_today.index[env.current_time[0]
#                       ^
# SyntaxError: '[' was never closed

# %%
import ray
from ray.rllib.algorithms.dqn import DQNConfig

# Initialize Ray
ray.init(ignore_reinit_error=True)
# Out:
# 2025-03-12 11:24:10,431	INFO worker.py:1672 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='', python_version='3.11.11', ray_version='2.43.0', ray_commit='ecdcdc6a6e63dc4bcd6ea16aae256ce4d32a7e2c')

# %%
config = (
    DQNConfig()
    .training(
        gamma=0.99,  # Discount factor for rewards
        lr=0.001,  # Learning rate
        train_batch_size=32,  # Batch size for training
    )
    .environment(
        env="CartPole-v1",  # Replace with your custom environment (e.g., "MaskedSimEnv")
    )
    .resources(
        num_gpus=0  # Set to 1 if using GPU
    )
    .env_runners(
        num_env_runners=1  # ✅ Replace num_rollout_workers with num_env_runners
    )
)

# %%
from stable_baselines3 import DQN

# Create & validate environment
env = SimEnv(df)
check_env(env)  # Check if it follows OpenAI Gym API

# Define the DQN model
model = DQN(
    "MlpPolicy",
    env,
    learning_rate=0.001,
    batch_size=32,
    buffer_size=10000,
    verbose=1,
    gradient_steps=1,
    max_grad_norm=10  # ✅ Prevents exploding gradients
)
# Train the model
model.learn(total_timesteps=100000)

# Save the trained model
model.save("dqn_options_trading2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       1 from stable_baselines3 import DQN
#       3 # Create & validate environment
# ----> 4 env = SimEnv(df)
#       5 check_env(env)  # Check if it follows OpenAI Gym API
#       7 # Define the DQN model
#
# Cell In[41], line 49, in SimEnv.__init__(self, env_config)
#      47 # ✅ Ensure df is provided
#      48 if self.df is None:
# ---> 49     raise ValueError("Error: `df` must be provided in env_config!")
#      51 # ✅ Initialize other attributes
#      52 self.df_today = None
#
# ValueError: Error: `df` must be provided in env_config!

# %%
from stable_baselines3 import DQN

#model = DQN.load("dqn_options_trading", env=env)  # ✅ Load the trained model
model = DQN.load("dqn_options_trading2", env=env)  # ✅ Load the trained model
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
new_env=SimEnv(df)
obs=new_env.reset()[0]
new_env.done
# Out:
# False

# %%
num_episodes=500
new_env=SimEnv(df)
pl=[]
num_steps=[]
for i in range(1,num_episodes):

    obs=new_env.reset()[0]
    done = False
    i=0
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        (obs, reward, done, truncated, info) = new_env.step(action)
        i=i+1
    num_steps.append(i)
    pl.append(reward)

# %%
average_pl=sum(pl)/len(pl)
average_steps=sum(num_steps)/len(num_steps)
print(f"average_pl={average_pl}, average_steps={average_steps}")
# Out:
# average_pl=-1.8627339882481264, average_steps=2.0

# %%
import gymnasium as gym  # ✅ Use gymnasium instead of gym
import numpy as np
import pandas as pd
from gymnasium import spaces

class SimEnv(gym.Env):
    """
    Custom Options Trading Environment for Reinforcement Learning.
    """
    def __init__(self, df):
        super(SimEnv, self).__init__()
        
        # Market Data
        self.df = df
        self.df_today = None
        
        # Index Tracking
        self.global_index = 0
        self.daily_index = 0
        self.start_index = 0
        self.max_steps = 62  # Max steps per episode

        # Trading Variables
        self.position = 0
        self.entry_price = 0
        self.position_open_time = None

        # Capital & PnL
        self.capital = 100
        self.pnl = 0
        self.position_value = 0

        # Episode State
        self.done = False
        self.current_row = None

        # Action & Observation Space
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Open, 2: Close
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(11,), dtype=np.float32)

    def __init__(self, env_config):
        super(SimEnv, self).__init__()
        
        # ✅ Read `df` from `env_config`
        self.df = env_config.get("df")
        
        # ✅ Ensure df is provided
        if self.df is None:
            raise ValueError("Error: `df` must be provided in env_config!")
        
        # ✅ Initialize other attributes
        self.df_today = None
        self.global_index = 0
        self.max_steps = 62  # Max steps per episode

        self.position = 0
        self.entry_price = 0
        self.pnl = 0
        self.done = False
        self.current_row = None
        
        self.action_space = spaces.Discrete(3)  # 0: Hold, 1: Open, 2: Close
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(11,), dtype=np.float32)

    def reset(self, seed=None):
        """ Reset environment and start a new episode. """
        self.global_index = self.pick_episode_start()
        self.daily_index = self.df_today.index.get_loc(self.global_index)
        self.start_index = self.global_index
        self.done = False
        self.position = 0
        self.pnl = 0

        # Compute daily straddle prices before trading starts
        straddle_prices = self.compute_daily_atm_straddle_prices()
        self.df_today["daily_straddle_prices"] = straddle_prices
        self.df_today["open_straddle_pnl"] = 0

        obs = self._get_state()  # Observation (state)
        action_mask = self.compute_action_mask()  # ✅ Compute action mask for valid actions
        info = {"action_mask": action_mask}  # ✅ Include action mask in `info`

        return obs, info  # ✅ Must return a tuple (obs, info)

    def compute_action_mask(self):
        """ Computes an action mask where invalid actions are marked as 0. """
        action_mask = np.array([1, 1, 1])  # Default: all actions allowed
        
        if self.position == 0:
            action_mask[2] = 0  # Can't close if no position is open
        else:
            action_mask[1] = 0  # Can't open a new position if one is already open
        
        return action_mask  # ✅ Masked actions for Rllib

    def step(self, action):
        """ Execute the selected action. """
        reward = 0.0
        allowed_actions = self.valid_actions()

        if action not in allowed_actions:
            reward = -1000  # Strong penalty for invalid action
            truncated = True
            self.done = True
            return self._get_state(), reward, self.done, truncated, {"action_mask": self.compute_action_mask()}  # ✅ Return action mask

        if action == 1 and self.position == 0:  # Open position
            self.open_position()
            self.update_time_step(60)

        elif action == 2 and self.position > 0:  # Close position
            reward = self.df_today["open_straddle_pnl"].loc[self.global_index] - self.pnl
            self.pnl = self.df_today["open_straddle_pnl"].loc[self.global_index]
            self.position = 0
            self.done = True

        elif action == 3:  # Hold position
            if self.position > 0:
                reward = self.df_today["open_straddle_pnl"].loc[self.global_index] - self.pnl
                self.pnl = self.df_today["open_straddle_pnl"].loc[self.global_index]
            
            self.update_time_step(1)

        # End episode if time exceeds max steps
        if self.global_index - self.start_index >= self.max_steps:
            self.done = True

        return self._get_state(), reward, self.done, False, {"action_mask": self.compute_action_mask()}  # ✅ Return action mask

    def valid_actions(self):
        if self.position == 0:
            return [1, 3]
        else:
            return [2, 3]

    def render(self, mode="human"):
        """ Optional: Print state information for debugging. """
        print(f"Time: {self.df.iloc[self.global_index]['minute']}, Position: {self.position}, PnL: {self.pnl}")

    def close(self):
        pass
    def open_position(self):

        ivol = self.get_current_row()['implied_spot']
        texp = self.get_current_row()['years_to_maturity']
        spot=self.get_current_row()['implied_spot']
        #straddle_price_1 = self.price_one_day_straddle(texp, ivol)
        straddle_price=self.df_today['daily_straddle_prices'].loc[self.global_index]
        #print(f"straddle_price={straddle_price}")
        #print(f"straddle_price_1={straddle_price_1}")
        if (straddle_price == 0):
            print(f"eror: straddle_price={straddle_price}. at time={self.get_current_time()}")
        self.position = self.capital / straddle_price
        #self.position_value = self.position * straddle_price
        self.strike=spot
        #spot_vols=self.compute_spot_vols(self.strike)
        self.straddle_prices=self.compute_straddle_prices(self.strike)
        self.df_today["open_straddle_prices"]=self.straddle_prices
        self.df_today["open_straddle_pnl"]=(self.df_today["open_straddle_prices"]- straddle_price)*self.position
        self.position_open_time = self.global_index
        return self.position_value

# %%
import ray
from ray.rllib.algorithms.dqn import DQNConfig

# Initialize Ray
ray.init(ignore_reinit_error=True)
# Out:
# 2025-03-12 15:34:47,413	INFO worker.py:1672 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='', python_version='3.11.11', ray_version='2.43.0', ray_commit='ecdcdc6a6e63dc4bcd6ea16aae256ce4d32a7e2c')

# %%
config = DQNConfig()  # ✅ Ensure config is initialized correctly
config = (
    DQNConfig()
    .training(
        gamma=0.99,  # Discount factor
        lr=0.001,  # Learning rate
        train_batch_size=32,  # Batch size
    )
    .environment(
        env=SimEnv,  # ✅ Use your custom environment
    )
    .resources(
        num_gpus=0  # Set to 1 if using GPU
    )
    .env_runners(
        num_env_runners=1  # ✅ Replaces deprecated `num_rollout_workers`
    )
)

# %%
# Create the DQN agent using the configured settings
dqn_agent = config.build()

# Train the agent for a number of iterations
for i in range(10):
    result = dqn_agent.train()
    print(f"Iteration {i}: Reward = {result['episode_reward_mean']}")
# Out:
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:512: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-03-12 15:34:54,972	ERROR actor_manager.py:833 -- Ray error (The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=87475, ip=127.0.0.1, actor_id=3107308e98efae1c7c4b77b101000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x15bdae1d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 100, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 654, in make_env
#     gym.make_vec(
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 918, in make_vec
#     env = gym.vector.SyncVectorEnv(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py", line 86, in __init__
#     self.envs = [env_fn() for env_fn in env_fns]
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py", line 86, in <listcomp>
#     self.envs = [env_fn() for env_fn in env_fns]
#                  ^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 903, in create_single_env
#     single_env = make(env_spec, **env_spec_kwargs.copy())
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 740, in make
#     env = env_creator(**env_spec_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/utils/__init__.py", line 118, in _gym_env_creator
#     env = env_descriptor(env_context)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/c1/dv7w7b2x49j3spqsxnz6y_sw0000gn/T/ipykernel_53828/861749123.py", line 49, in __init__
# ValueError: Error: `df` must be provided in env_config!), taking actor 1 out of service.
# 2025-03-12 15:34:54,973	ERROR env_runner_group.py:689 -- Validation of EnvRunner failed! Error=The actor died because of an error raised in its creation task, ray::SingleAgentEnvRunner.__init__() (pid=87475, ip=127.0.0.1, actor_id=3107308e98efae1c7c4b77b101000000, repr=<ray.rllib.env.single_agent_env_runner.SingleAgentEnvRunner object at 0x15bdae1d0>)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 100, in __init__
#     self.make_env()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py", line 654, in make_env
#     gym.make_vec(
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 918, in make_vec
#     env = gym.vector.SyncVectorEnv(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py", line 86, in __init__
#     self.envs = [env_fn() for env_fn in env_fns]
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py", line 86, in <listcomp>
#     self.envs = [env_fn() for env_fn in env_fns]
#                  ^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 903, in create_single_env
#     single_env = make(env_spec, **env_spec_kwargs.copy())
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py", line 740, in make
#     env = env_creator(**env_spec_kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/utils/__init__.py", line 118, in _gym_env_creator
#     env = env_descriptor(env_context)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/c1/dv7w7b2x49j3spqsxnz6y_sw0000gn/T/ipykernel_53828/861749123.py", line 49, in __init__
# ValueError: Error: `df` must be provided in env_config!
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment rllib-single-agent-env-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # Create the DQN agent using the configured settings
# ----> 2 dqn_agent = config.build()
#       4 # Train the agent for a number of iterations
#       5 for i in range(10):
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/utils/deprecation.py:128, in Deprecated.<locals>._inner.<locals>._ctor(*args, **kwargs)
#     121     deprecation_warning(
#     122         old=old or obj.__name__,
#     123         new=new,
#     124         help=help,
#     125         error=error,
#     126     )
#     127 # Call the deprecated method/function.
# --> 128 return obj(*args, **kwargs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm_config.py:5417, in AlgorithmConfig.build(self, *args, **kwargs)
#    5415 @Deprecated(new="AlgorithmConfig.build_algo", error=False)
#    5416 def build(self, *args, **kwargs):
# -> 5417     return self.build_algo(*args, **kwargs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm_config.py:958, in AlgorithmConfig.build_algo(self, env, logger_creator, use_copy)
#     955 if isinstance(self.algo_class, str):
#     956     algo_class = get_trainable_cls(self.algo_class)
# --> 958 return algo_class(
#     959     config=self if not use_copy else copy.deepcopy(self),
#     960     logger_creator=self.logger_creator,
#     961 )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:528, in Algorithm.__init__(self, config, env, logger_creator, **kwargs)
#     525 # Evaluation EnvRunnerGroup and metrics last returned by `self.evaluate()`.
#     526 self.eval_env_runner_group: Optional[EnvRunnerGroup] = None
# --> 528 super().__init__(
#     529     config=config,
#     530     logger_creator=logger_creator,
#     531     **kwargs,
#     532 )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:157, in Trainable.__init__(self, config, logger_creator, storage)
#     153     logger.debug(f"StorageContext on the TRAINABLE:\n{storage}")
#     155 self._open_logfiles(stdout_file, stderr_file)
# --> 157 self.setup(copy.deepcopy(self.config))
#     158 setup_time = time.time() - self._start_time
#     159 if setup_time > SETUP_TIME_THRESHOLD:
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:631, in Algorithm.setup(self, config)
#     627     self.offline_data = None
#     629 if not self.offline_data:
#     630     # Create a set of env runner actors via a EnvRunnerGroup.
# --> 631     self.env_runner_group = EnvRunnerGroup(
#     632         env_creator=self.env_creator,
#     633         validate_env=self.validate_env,
#     634         default_policy_class=self.get_default_policy_class(self.config),
#     635         config=self.config,
#     636         local_env_runner=True,
#     637         logdir=self.logdir,
#     638         tune_trial_id=self.trial_id,
#     639     )
#     641 # Compile, validate, and freeze an evaluation config.
#     642 self.evaluation_config = self.config.get_evaluation_config_object()
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:198, in EnvRunnerGroup.__init__(self, env_creator, validate_env, default_policy_class, config, local_env_runner, logdir, _setup, tune_trial_id, pg_offset, num_env_runners, num_workers, local_worker)
#     196 if _setup:
#     197     try:
# --> 198         self._setup(
#     199             validate_env=validate_env,
#     200             config=config,
#     201             num_env_runners=(
#     202                 num_env_runners
#     203                 if num_env_runners is not None
#     204                 else config.num_env_runners
#     205             ),
#     206             local_env_runner=local_env_runner,
#     207         )
#     208     # EnvRunnerGroup creation possibly fails, if some (remote) workers cannot
#     209     # be initialized properly (due to some errors in the EnvRunners's
#     210     # constructor).
#     211     except RayActorError as e:
#     212         # In case of an actor (remote worker) init failure, the remote worker
#     213         # may still exist and will be accessible, however, e.g. calling
#     214         # its `sample.remote()` would result in strange "property not found"
#     215         # errors.
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:293, in EnvRunnerGroup._setup(self, validate_env, config, num_env_runners, local_env_runner)
#     291 # Create a local worker, if needed.
#     292 if local_env_runner:
# --> 293     self._local_env_runner = self._make_worker(
#     294         env_creator=self._env_creator,
#     295         validate_env=validate_env,
#     296         worker_index=0,
#     297         num_workers=num_env_runners,
#     298         config=self._local_config,
#     299         spaces=spaces,
#     300     )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:1207, in EnvRunnerGroup._make_worker(self, env_creator, validate_env, worker_index, num_workers, recreated_worker, config, spaces)
#    1192 kwargs = dict(
#    1193     env_creator=env_creator,
#    1194     validate_env=validate_env,
#    (...)   1203     tune_trial_id=self._tune_trial_id,
#    1204 )
#    1206 if worker_index == 0:
# -> 1207     return self.env_runner_cls(**kwargs)
#    1209 pg_bundle_idx = (
#    1210     -1
#    1211     if ray.util.get_current_placement_group() is None
#    1212     else self._pg_offset + worker_index
#    1213 )
#    1214 return (
#    1215     ray.remote(**self._remote_args)(self.env_runner_cls)
#    1216     .options(placement_group_bundle_index=pg_bundle_idx)
#    1217     .remote(**kwargs)
#    1218 )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py:100, in SingleAgentEnvRunner.__init__(self, config, **kwargs)
#      98 self.env: Optional[gym.vector.VectorEnvWrapper] = None
#      99 self.num_envs: int = 0
# --> 100 self.make_env()
#     102 # Create the env-to-module connector pipeline.
#     103 self._env_to_module = self.config.build_env_to_module_connector(
#     104     self.env, device=self._device
#     105 )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/single_agent_env_runner.py:654, in SingleAgentEnvRunner.make_env(self)
#     650 gym.register("rllib-single-agent-env-v0", entry_point=entry_point)
#     651 vectorize_mode = self.config.gym_env_vectorize_mode
#     653 self.env = DictInfoToList(
# --> 654     gym.make_vec(
#     655         "rllib-single-agent-env-v0",
#     656         num_envs=self.config.num_envs_per_env_runner,
#     657         vectorization_mode=(
#     658             vectorize_mode
#     659             if isinstance(vectorize_mode, gym.envs.registration.VectorizeMode)
#     660             else gym.envs.registration.VectorizeMode(vectorize_mode.lower())
#     661         ),
#     662     )
#     663 )
#     665 self.num_envs: int = self.env.num_envs
#     666 assert self.num_envs == self.config.num_envs_per_env_runner
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py:918, in make_vec(id, num_envs, vectorization_mode, vector_kwargs, wrappers, **kwargs)
#     913     if env_spec.entry_point is None:
#     914         raise error.Error(
#     915             f"Cannot create vectorized environment for {env_spec.id} because it doesn't have an entry point defined."
#     916         )
# --> 918     env = gym.vector.SyncVectorEnv(
#     919         env_fns=(create_single_env for _ in range(num_envs)),
#     920         **vector_kwargs,
#     921     )
#     922 elif vectorization_mode == VectorizeMode.ASYNC:
#     923     if env_spec.entry_point is None:
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py:86, in SyncVectorEnv.__init__(self, env_fns, copy, observation_mode)
#      83 self.observation_mode = observation_mode
#      85 # Initialise all sub-environments
# ---> 86 self.envs = [env_fn() for env_fn in env_fns]
#      88 # Define core attributes using the sub-environments
#      89 # As we support `make_vec(spec)` then we can't include a `spec = self.envs[0].spec` as this doesn't guarantee we can actual recreate the vector env.
#      90 self.num_envs = len(self.envs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/vector/sync_vector_env.py:86, in <listcomp>(.0)
#      83 self.observation_mode = observation_mode
#      85 # Initialise all sub-environments
# ---> 86 self.envs = [env_fn() for env_fn in env_fns]
#      88 # Define core attributes using the sub-environments
#      89 # As we support `make_vec(spec)` then we can't include a `spec = self.envs[0].spec` as this doesn't guarantee we can actual recreate the vector env.
#      90 self.num_envs = len(self.envs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py:903, in make_vec.<locals>.create_single_env()
#     902 def create_single_env() -> Env:
# --> 903     single_env = make(env_spec, **env_spec_kwargs.copy())
#     905     if wrappers is None:
#     906         return single_env
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py:740, in make(id, max_episode_steps, disable_env_checker, **kwargs)
#     734         logger.warn(
#     735             f"The environment is being initialised with render_mode={render_mode!r} "
#     736             f"that is not in the possible render_modes ({render_modes})."
#     737         )
#     739 try:
# --> 740     env = env_creator(**env_spec_kwargs)
#     741 except TypeError as e:
#     742     if (
#     743         str(e).find("got an unexpected keyword argument 'render_mode'") >= 0
#     744         and apply_human_rendering
#     745     ):
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/utils/__init__.py:118, in _gym_env_creator(env_context, env_descriptor)
#     115 try:
#     116     # If class provided, call constructor directly.
#     117     if isinstance(env_descriptor, type):
# --> 118         env = env_descriptor(env_context)
#     119     else:
#     120         env = gym.make(env_descriptor, **env_context)
#
# Cell In[41], line 49, in SimEnv.__init__(self, env_config)
#      47 # ✅ Ensure df is provided
#      48 if self.df is None:
# ---> 49     raise ValueError("Error: `df` must be provided in env_config!")
#      51 # ✅ Initialize other attributes
#      52 self.df_today = None
#
# ValueError: Error: `df` must be provided in env_config!

# %%
config = DQNConfig()  # ✅ Ensure config is initialized correctly

# %%
config = DQNConfig()
config = (
    config.training(
        gamma=0.99,  # Discount factor
        lr=0.001,  # Learning rate
        train_batch_size=32,  # Batch size
    )
    .environment(
        env=SimEnv,  # ✅ Use your custom environment
        env_config={"df": df},  # ✅ Pass `df` inside `env_config`
    )
    .resources(
        num_gpus=0  # Set to 1 if using GPU
    )
    .env_runners(
        num_env_runners=1  # ✅ Replaces deprecated `num_rollout_workers`
    )
)
"""
config.update_from_dict({
    "exploration_config": {
        "type": "EpsilonGreedy",
        "initial_epsilon": 1.0,
        "final_epsilon": 0.01,
        "epsilon_timesteps": 50000,
    }
})
"""
# ✅ Now build the agent
dqn_agent = config.build()
print(dqn_agent)
# Out:
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:512: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/gymnasium/envs/registration.py:642: UserWarning: WARN: Overriding environment rllib-single-agent-env-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-03-12 12:23:23,921	WARNING util.py:61 -- Install gputil for GPU system monitoring.
# DQN(env=<class '__main__.SimEnv'>; env-runners=1; learners=0; multi-agent=False)

# %%
for i in range(10):
    result = dqn_agent.train()
    print(f"Iteration {i}: Reward = {result['episode_reward_mean']}")
# Out:
# 2025-03-12 12:24:24,198	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:24:25,947	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:24:25,948	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:24:25,948	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:24:27,956	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:24:27,963	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:25:28,210	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:25:30,049	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:25:30,049	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:25:30,049	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:25:32,052	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:25:32,057	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:26:32,320	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:26:34,134	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:26:34,135	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:26:34,135	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:26:36,139	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:26:36,148	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:27:36,367	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:27:38,254	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:27:38,255	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:27:38,255	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:27:40,257	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:27:40,262	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:28:40,522	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:28:42,365	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:28:42,365	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:28:42,366	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:28:44,368	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:28:44,374	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:29:44,624	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:29:46,473	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:29:46,474	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:29:46,474	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:29:48,475	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:29:48,479	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:30:48,717	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:30:50,572	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:30:50,572	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:30:50,572	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:30:52,574	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:30:52,581	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:31:52,850	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:31:54,658	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:31:54,659	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:31:54,659	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:31:56,663	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:31:56,670	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:32:56,894	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:32:58,745	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:32:58,745	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:32:58,745	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:33:00,747	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:33:00,752	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:34:00,990	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:34:02,841	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:34:02,841	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:34:02,842	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:34:04,846	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:34:04,854	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:35:05,101	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:35:06,938	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:35:06,938	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:35:06,938	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:35:08,948	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:35:08,954	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:36:09,185	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:36:11,047	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:36:11,047	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:36:11,047	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:36:13,052	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:36:13,060	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:37:13,320	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:37:15,143	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:37:15,143	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:37:15,144	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:37:17,144	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:37:17,147	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:38:17,379	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:38:19,240	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:38:19,241	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:38:19,241	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:38:21,249	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:38:21,254	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:39:21,490	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:39:23,349	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:39:23,350	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:39:23,350	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:39:25,353	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:39:25,358	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:40:25,620	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:40:27,449	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:40:27,449	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:40:27,450	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:40:29,454	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:40:29,461	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:41:29,697	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:41:31,542	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:41:31,543	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:41:31,543	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:41:33,544	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:41:33,547	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:42:33,772	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:42:35,651	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:42:35,652	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:42:35,652	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:42:37,654	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:42:37,658	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:43:37,914	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:43:39,741	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:43:39,741	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:43:39,742	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:43:41,743	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:43:41,749	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:44:41,972	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:44:43,833	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:44:43,834	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:44:43,834	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:44:45,836	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:44:45,841	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:45:46,072	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:45:47,932	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:45:47,932	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:45:47,932	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:45:49,935	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:45:49,939	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:47:12,423	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:47:13,882	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:47:13,883	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:47:13,883	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:47:15,886	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:47:15,898	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 12:49:51,979	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:49:53,486	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 12:49:53,487	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 12:49:53,487	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:52:38,006	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:52:40,008	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 12:52:40,014	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 14:00:34,995	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 14:00:36,660	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 14:00:36,660	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 14:00:36,661	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 14:16:59,761	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 14:16:59,770	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 14:59:36,603	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:01:12,415	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:01:12,420	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:01:12,422	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:01:14,409	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:01:16,412	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:01:16,418	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:02:16,652	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:02:18,521	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:02:18,522	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:02:18,522	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:02:20,527	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:02:20,533	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:03:20,773	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:03:22,629	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:03:22,630	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:03:22,630	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:03:24,632	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:03:24,637	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:04:24,866	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:04:26,752	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:04:26,752	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:04:26,753	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:04:28,755	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:04:28,759	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:05:28,999	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:05:30,857	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:05:30,858	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:05:30,858	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:05:32,859	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:05:32,864	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:06:33,070	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:06:34,950	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:06:34,950	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:06:34,951	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:06:36,955	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:06:36,963	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:07:37,221	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:07:39,062	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:07:39,062	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:07:39,063	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:07:41,063	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:07:41,066	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# 2025-03-12 15:08:41,298	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:08:43,162	ERROR actor_manager.py:833 -- Ray error (The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.), taking actor 1 out of service.
# 2025-03-12 15:08:43,162	ERROR actor_manager.py:651 -- The actor cf793be60bcb50a0f3d7922301000000 is unavailable: The actor is temporarily unavailable: IOError: The actor is restarting.. The task may or maynot have been executed on the actor.
# NoneType: None
# 2025-03-12 15:08:43,163	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:08:45,164	WARNING rollout_ops.py:121 -- No samples returned from remote workers. If you have a slow environment or model, consider increasing the `sample_timeout_s` or decreasing the `rollout_fragment_length` in `AlgorithmConfig.env_runners().
# 2025-03-12 15:08:45,171	WARNING actor_manager.py:846 -- Bringing previously unhealthy, now-healthy actor 1 back into service.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 for i in range(10):
# ----> 2     result = dqn_agent.train()
#       3     print(f"Iteration {i}: Reward = {result['episode_reward_mean']}")
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/tune/trainable/trainable.py:327, in Trainable.train(self)
#     325 start = time.time()
#     326 try:
# --> 327     result = self.step()
#     328 except Exception as e:
#     329     skipped = skip_exceptions(e)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:964, in Algorithm.step(self)
#     959 # - No evaluation necessary, just run the next training iteration.
#     960 # - We have to evaluate in this training iteration, but no parallelism ->
#     961 #   evaluate after the training iteration is entirely done.
#     962 else:
#     963     if self.config.enable_env_runner_and_connector_v2:
# --> 964         train_results, train_iter_ctx = self._run_one_training_iteration()
#     965     else:
#     966         (
#     967             train_results,
#     968             train_iter_ctx,
#     969         ) = self._run_one_training_iteration_old_api_stack()
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:2991, in Algorithm._run_one_training_iteration(self)
#    2989 # Try to train one step.
#    2990 with self.metrics.log_time((TIMERS, TRAINING_STEP_TIMER)):
# -> 2991     training_step_return_value = self.training_step()
#    2992     has_run_once = True
#    2994 # On the new API stack, results should NOT be returned anymore as
#    2995 # a dict, but purely logged through the `MetricsLogger` API. This
#    2996 # way, we make sure to never miss a single stats/counter/timer
#    2997 # when calling `self.training_step()` more than once within the same
#    2998 # iteration.
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/dqn/dqn.py:630, in DQN.training_step(self)
#     627     return self._training_step_old_api_stack()
#     629 # New API stack (RLModule, Learner, EnvRunner, ConnectorV2).
# --> 630 return self._training_step_new_api_stack()
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/algorithms/dqn/dqn.py:640, in DQN._training_step_new_api_stack(self)
#     637 for _ in range(store_weight):
#     638     with self.metrics.log_time((TIMERS, ENV_RUNNER_SAMPLING_TIMER)):
#     639         # Sample in parallel from workers.
# --> 640         episodes, env_runner_results = synchronous_parallel_sample(
#     641             worker_set=self.env_runner_group,
#     642             concat=True,
#     643             sample_timeout_s=self.config.sample_timeout_s,
#     644             _uses_new_env_runners=True,
#     645             _return_metrics=True,
#     646         )
#     647     # Reduce EnvRunner metrics over the n EnvRunners.
#     648     self.metrics.merge_and_log_n_dicts(
#     649         env_runner_results, key=ENV_RUNNER_RESULTS
#     650     )
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/execution/rollout_ops.py:106, in synchronous_parallel_sample(worker_set, max_agent_steps, max_env_steps, concat, sample_timeout_s, random_actions, _uses_new_env_runners, _return_metrics)
#     103         stats_dicts = [worker_set.local_env_runner.get_metrics()]
#     104 # Loop over remote workers' `sample()` method in parallel.
#     105 else:
# --> 106     sampled_data = worker_set.foreach_env_runner(
#     107         (
#     108             (lambda w: w.sample(**random_action_kwargs))
#     109             if not _return_metrics
#     110             else (lambda w: (w.sample(**random_action_kwargs), w.get_metrics()))
#     111         ),
#     112         local_env_runner=False,
#     113         timeout_seconds=sample_timeout_s,
#     114     )
#     115     # Nothing was returned (maybe all workers are stalling) or no healthy
#     116     # remote workers left: Break.
#     117     # There is no point staying in this loop, since we will not be able to
#     118     # get any new samples if we don't have any healthy remote workers left.
#     119     if not sampled_data or worker_set.num_healthy_remote_workers() <= 0:
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/env/env_runner_group.py:767, in EnvRunnerGroup.foreach_env_runner(self, func, local_env_runner, healthy_only, remote_worker_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     764 if not self._worker_manager.actor_ids():
#     765     return local_result
# --> 767 remote_results = self._worker_manager.foreach_actor(
#     768     func,
#     769     healthy_only=healthy_only,
#     770     remote_actor_ids=remote_worker_ids,
#     771     timeout_seconds=timeout_seconds,
#     772     return_obj_refs=return_obj_refs,
#     773     mark_healthy=mark_healthy,
#     774 )
#     776 FaultTolerantActorManager.handle_remote_call_result_errors(
#     777     remote_results, ignore_ray_errors=self._ignore_ray_errors_on_env_runners
#     778 )
#     780 # With application errors handled, return good results.
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:459, in FaultTolerantActorManager.foreach_actor(self, func, healthy_only, remote_actor_ids, timeout_seconds, return_obj_refs, mark_healthy)
#     453 remote_calls = self._call_actors(
#     454     func=func,
#     455     remote_actor_ids=remote_actor_ids,
#     456 )
#     458 # Collect remote request results (if available given timeout and/or errors).
# --> 459 _, remote_results = self._fetch_result(
#     460     remote_actor_ids=remote_actor_ids,
#     461     remote_calls=remote_calls,
#     462     tags=[None] * len(remote_calls),
#     463     timeout_seconds=timeout_seconds,
#     464     return_obj_refs=return_obj_refs,
#     465     mark_healthy=mark_healthy,
#     466 )
#     468 return remote_results
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/rllib/utils/actor_manager.py:799, in FaultTolerantActorManager._fetch_result(self, remote_actor_ids, remote_calls, tags, timeout_seconds, return_obj_refs, mark_healthy)
#     796 if not remote_calls:
#     797     return [], RemoteCallResults()
# --> 799 readies, _ = ray.wait(
#     800     remote_calls,
#     801     num_returns=len(remote_calls),
#     802     timeout=timeout,
#     803     # Make sure remote results are fetched locally in parallel.
#     804     fetch_local=not return_obj_refs,
#     805 )
#     807 # Remote data should already be fetched to local object store at this point.
#     808 remote_results = RemoteCallResults()
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/_private/auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File /Applications/anaconda3/envs/ml_env2/lib/python3.11/site-packages/ray/_private/worker.py:3002, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    3000 timeout = timeout if timeout is not None else 10**6
#    3001 timeout_milliseconds = int(timeout * 1000)
# -> 3002 ready_ids, remaining_ids = worker.core_worker.wait(
#    3003     ray_waitables,
#    3004     num_returns,
#    3005     timeout_milliseconds,
#    3006     fetch_local,
#    3007 )
#    3008 return ready_ids, remaining_ids
#
# File python/ray/_raylet.pyx:3507, in ray._raylet.CoreWorker.wait()
#
# File python/ray/includes/common.pxi:83, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
config
